# %% [markdown]
# <a href="https://colab.research.google.com/github/sabrinakreyzerman-k/Python_Bootcamp/blob/day-1-exercise/day_1_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 1 Exercises

# %% [markdown]
# ## Data Types

# %% [markdown]
# 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5
# Out:
# 20.0

# %% [markdown]
# Data types involved: integer number (Int) (8) and floating point number (Float) (2.5)
# Data type evaluated to: Int (20)

# %%
9 / 2
# Out:
# 4.5

# %% [markdown]
# Data types involved: Ints (9 and 2)
# Data type evaluated to: Float (4.5)

# %%
1.5 * 2 >= 7 - 3
# Out:
# False

# %% [markdown]
# Data types involved: Float (1.5) and Ints (2, 7, and 3)
# Data type evaluated to: Bool (False)

# %% [markdown]
# 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4
# Out:
# 46

# %% [markdown]
# 6 * 3 = 18, 7 * 4 = 28, 18 + 28 = 46 (Multiplication followed by addition)

# %%
5 - 2 * 3 ** 4
# Out:
# -157

# %% [markdown]
# Exponentiation, followed by multiplication, followed by subtraction

# %%
(5 - 2) * 3 ** 4
# Out:
# 243

# %% [markdown]
# Parantheses first (subtraction), followed by exponentiation, followed by multiplication

# %%
5 + 2 >= 3 * 4
# Out:
# False

# %% [markdown]
# Multiplication, addition, greater than or equal to (7 is not greater than or equal to 12)

# %% [markdown]
# # Comments and Errors

# %% [markdown]
# 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# No error

# %%
84 * (0.5 / 7)
# Out:
# 6.0

# %% [markdown]
# Syntax error: Does not work as an augmented assignment because it cannot begin with a digit (also, augmented assignments are used to assign a value to a variable)

# %% [markdown]
# Solution:

# %%
84 * (0.5 / 7)
# Out:
# 6.0

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# No error

# %%
5 * 3 = weight
# Out:
#   File "/tmp/ipykernel_1809/3700621706.py", line 1
#     5 * 3 = weight
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# Syntax error: variable names cannot start with a digit

# %% [markdown]
# Solution:

# %%
weight = 5 * 3

# %%
73 / -----------5

# %% [markdown]
# No error

# %% [markdown]
# 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6
# If value is a string:
print("The value is valid.")
# If value is not a string:
raise Exception("The value must be a string.")

# %% [markdown]
# 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[2])

# %% [markdown]
# Index error: element [3] does not exist because [1, 2, 3] are assigned 0, 1, and 2 when sliced

# %% [markdown]
# Solution:

# %%
arr = [1, 2, 3]
print(arr[2])

# %% [markdown]
# 3 is the last element of arr, represented by [2]

# %%
fullName = "Taylor Swift"
print(full_name)

# %% [markdown]
# Name error: full_name is not defined (variable name written as fullName)

# %% [markdown]
# Solution:

# %%
full_name = "Taylor Swift"
print(full_name)

# %%
2 + '2' + 4

# %% [markdown]
# Type error: integer cannot be added to a string (incompatible)

# %% [markdown]
# Solutions:

# %%
2 + 2 + 4

# %%
'2' + '2' + '4'

# %% [markdown]
# # Functions

# %% [markdown]
# 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
def kilometers_to_miles (kilometers) :
  # Convert Kilometers to Miles
  return kilometers / 1.6

# %%
kilometers_to_miles(0)
# Out:
# 0.0

# %%
kilometers_to_miles(1.6)
# Out:
# 1.0

# %%
distance_miles = kilometers_to_miles(1.6)
distance_miles
# Out:
# 1.0

# %% [markdown]
# 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)
# Out:
# 3

# %% [markdown]
# Global scope (value defined outside the function) is 3, therefore, the printed value is 3

# %% [markdown]
# 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    ''
    >>> repeat('yesnomaybe', 3)
   'yesnomaybeyesnomaybeyesnomaybe'
    '''
    output = string * num
    return output

# %% [markdown]
# 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    # Clean the string by replacing parantheses, spaces, and hyphens with nothing
    cleaned_number = number.replace('()-,-').replace(',,').replace(',')

    # Check if the first three digits of the cleaned string are '416'
    return cleaned_number[:3] == '416'
